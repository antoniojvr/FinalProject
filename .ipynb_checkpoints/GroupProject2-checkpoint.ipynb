# %% [markdown]
# Importing the necessary libraries for analysis.

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt

from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.cross_validation import train_test_split
from sklearn.metrics import accuracy_score

# %matplotlib inline

# %% [markdown]
# Import the data to be analyzed.

# %%
dt = pd.read_excel('codeschoo.xls')

# %%
dt.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo Bootcampme  BootcampPostSalary  \
# 0                NaN                NaN        NaN                 NaN
# 1                NaN                NaN        NaN                 NaN
# 2                NaN                NaN        NaN                 NaN
# 3                NaN                NaN        NaN                 NaN
# 4                NaN                NaN        NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber       ...       ResourceSoloLearn  \
# 0                NaN             NaN       ...                     NaN
# 1                NaN             NaN       ...                     NaN
# 2                NaN             NaN       ...                     NaN
# 3                NaN             NaN       ...                     NaN
# 4                NaN             NaN       ...                     NaN
#
#    ResourceStackOverflow  ResourceTreehouse  ResourceUdacity  ResourceUdemy  \
# 0                    NaN                NaN              NaN            NaN
# 1                    NaN                NaN              NaN            1.0
# 2                    NaN                NaN              NaN            NaN
# 3                    NaN                NaN              NaN            NaN
# 4                    NaN                NaN              NaN            NaN
#
#    ResourceW3Schools  ResourceYouTube  \
# 0                NaN              NaN
# 1                NaN              NaN
# 2                NaN              NaN
# 3                NaN              NaN
# 4                NaN              NaN
#
#                               SchoolDegree              SchoolMajor  \
# 0           some college credit, no degree                      NaN
# 1           some college credit, no degree                      NaN
# 2  high school diploma or equivalent (GED)                      NaN
# 3                        bachelor's degree  Cinematography And Film
# 4           some college credit, no degree                      NaN
#
#    StudentDebtOwe
# 0         20000.0
# 1             NaN
# 2             NaN
# 3          7000.0
# 4             NaN
#
# [5 rows x 113 columns]

# %% [markdown]
# Remove columns that have more `NaN` that the defined threshold and view the remaining columns.

# %%
pct_null_thresh = 0.55
max_number_of_nans = pct_null_thresh * dt.shape[0]
dt_sub1 = dt.drop(dt.columns[dt.apply(lambda col: col.isnull().sum() > max_number_of_nans)], axis=1)

# %%
list(dt_sub1.columns)
# Out:
# ['Age',
#  'AttendedBootcamp',
#  'CityPopulation',
#  'CodeEventNone',
#  'CommuteTime',
#  'CountryCitizen',
#  'CountryLive',
#  'EmploymentField',
#  'EmploymentStatus',
#  'Gender',
#  'HasDebt',
#  'HasFincialDependents',
#  'HasHighSpdInternet',
#  'HasServedInMilitary',
#  'HoursLearning',
#  'ID.x',
#  'ID.y',
#  'Income',
#  'IsEthnicMinority',
#  'IsReceiveDiabilitiesBenefits',
#  'IsSoftwareDev',
#  'IsUnderEmployed',
#  'JobPref',
#  'LanguageAtHome',
#  'MoneyForLearning',
#  'MonthsProgramming',
#  'NetworkID',
#  'Part1EndTime',
#  'Part1StartTime',
#  'Part2EndTime',
#  'Part2StartTime',
#  'PodcastNone',
#  'ResourceCodecademy',
#  'ResourceFCC',
#  'SchoolDegree',
#  'SchoolMajor']

# %% [markdown]
# Remove additional columns because they will not be used.

# %%
_s = ['ID.x', 'ID.y', 'NetworkID', 'SchoolMajor', 'LanguageAtHome', 'CountryLive']

for col in _s:
    del dt_sub1[col]

# %% [markdown]
# Convert all `CountryCitizen` values to `1` if equal to `'United States of America'`.  Else, `0`.

# %%
dt_sub1['CountryCitizen'] = (dt_sub1['CountryCitizen'] == 'United States of America').astype(int)

# %% [markdown]
# Investigate the type of data in each remaining variable.

# %%
dt_sub1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15620 entries, 0 to 15619
# Data columns (total 30 columns):
# Age                             13613 non-null float64
# AttendedBootcamp                15380 non-null float64
# CityPopulation                  13630 non-null object
# CodeEventNone                   8900 non-null float64
# CommuteTime                     8339 non-null float64
# CountryCitizen                  15620 non-null int32
# EmploymentField                 7608 non-null object
# EmploymentStatus                12904 non-null object
# Gender                          13746 non-null object
# HasDebt                         13610 non-null float64
# HasFincialDependents            13640 non-null float64
# HasHighSpdInternet              13625 non-null float64
# HasServedInMilitary             13550 non-null float64
# HoursLearning                   14942 non-null float64
# Income                          7329 non-null float64
# IsEthnicMinority                13645 non-null float64
# IsReceiveDiabilitiesBenefits    13530 non-null float64
# IsSoftwareDev                   15537 non-null float64
# IsUnderEmployed                 8645 non-null float64
# JobPref                         11189 non-null object
# MoneyForLearning                14679 non-null float64
# MonthsProgramming               15014 non-null float64
# Part1EndTime                    15620 non-null datetime64[ns]
# Part1StartTime                  15620 non-null datetime64[ns]
# Part2EndTime                    13928 non-null datetime64[ns]
# Part2StartTime                  13928 non-null datetime64[ns]
# PodcastNone                     11040 non-null float64
# ResourceCodecademy              9586 non-null float64
# ResourceFCC                     10937 non-null float64
# SchoolDegree                    13679 non-null object
# dtypes: datetime64[ns](4), float64(19), int32(1), object(6)
# memory usage: 3.5+ MB

# %% [markdown]
# Seperate the categorical (object) columns.

# %%
cat_names = dt_sub1.loc[:, dt_sub1.dtypes == object].columns.values
cat_data = dt_sub1.loc[:, dt_sub1.dtypes == object]

# %%
cat_data.describe()
# Out:
#              CityPopulation              EmploymentField    EmploymentStatus  \
# count                 13630                         7608               12904
# unique                    3                           15                  10
# top     more than 1 million  software development and IT  Employed for wages
# freq                   5558                         4349                7201
#
#        Gender                          JobPref       SchoolDegree
# count   13746                            11189              13679
# unique      5                                5                 10
# top      male  work for a medium-sized company  bachelor's degree
# freq    10766                             3281               5644

# %%
dt_sub1.CityPopulation.value_counts().plot(kind='bar');

# %%
dt_sub1.EmploymentField.value_counts().plot(kind='bar');

# %%
dt_sub1.EmploymentStatus.value_counts().plot(kind='bar');

# %%
dt_sub1.Gender.value_counts().plot(kind='bar');

# %%
dt_sub1.JobPref.value_counts().plot(kind='bar');

# %%
dt_sub1.SchoolDegree.value_counts().plot(kind='bar');

# %%
dt_sub1.hist(layout = (12,3), xrot = 90, figsize  = (20, 40));

# %% [markdown]
# After removing the columns with a high amount of `NaN`, I reviewed the remaining columns and conluded that the following variables make sense to use in the regression:
# * `Age`
# * `CountryCitizen`
# * `Gender`
# * `Income`
# * `MonthsProgramming`
# * `SchoolDegree`

# %% [markdown]
# Create a sub-dataframe with the independent variables to be used in the regression.
# In addition, drop any observation that has an `NaN` or blank and simplify the data to only include `male` and `female` genders.

# %%
dt_sub2 = dt_sub1[['Age', 'CountryCitizen', 'Gender', 'Income', 'MonthsProgramming', 'SchoolDegree']]
dt_sub_noNA = dt_sub2.dropna()

# %%
dt_sub_noNA = dt_sub_noNA[~dt_sub_noNA['Gender'].isin(['genderqueer','agender', 'trans'])]

# %% [markdown]
# Convert all `SchoolDegree` values to a number `1` if coder has completed a four-year degree or higher, else `0`.
#
# Convert `male` and `female` to `1` and `0`, respectively.

# %%
dt_sub_noNA['SchoolDegree'] = (dt_sub_noNA['SchoolDegree'].isin(["Ph.D.", "master's degree (non-professiol)", "professiol degree (MBA, MD, JD, etc.)", "bachelor's degree"])).astype(int)

dt_sub_noNA['Gender'].replace(to_replace=["male", "female"], value=[1, 0], inplace=True)

# %%
dt_sub_noNA.hist(layout = (2,3), xrot = 90, figsize  = (20, 10));

# %% [markdown]
# Create Training and Testing datasets.

# %%
(X_train, X_test, y_train, y_test) = train_test_split(dt_sub_noNA[['CountryCitizen', 'Gender', 'Age', 'MonthsProgramming','SchoolDegree']], dt_sub_noNA['Income'],random_state=867, train_size=0.7)

# %% [markdown]
# Run `OLS` regression and print out a summary report.

# %%
#X_train = sm.add_constant(X_train)

model = sm.OLS(y_train, X_train)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Income   R-squared:                       0.681
# Model:                            OLS   Adj. R-squared:                  0.681
# Method:                 Least Squares   F-statistic:                     2120.
# Date:                Fri, 14 Apr 2017   Prob (F-statistic):               0.00
# Time:                        16:09:49   Log-Likelihood:                -58574.
# No. Observations:                4964   AIC:                         1.172e+05
# Df Residuals:                    4959   BIC:                         1.172e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------------
# CountryCitizen     1.464e+04    924.866     15.826      0.000      1.28e+04  1.65e+04
# Gender             5725.5028   1017.744      5.626      0.000      3730.274  7720.732
# Age                 762.9201     38.645     19.742      0.000       687.158   838.682
# MonthsProgramming   154.0373      8.505     18.111      0.000       137.363   170.711
# SchoolDegree       7407.8942    926.641      7.994      0.000      5591.267  9224.521
# ==============================================================================
# Omnibus:                     2052.106   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11300.429
# Skew:                           1.914   Prob(JB):                         0.00
# Kurtosis:                       9.323   Cond. No.                         146.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Model validation with testing set.

# %%
#X_test = sm.add_constant(X_test)

y_pred = results.predict(X_test)
print("Mean squared error: {:.2f}".format(np.mean((results.predict(X_test) - y_test) ** 2)))

print('\nThe coefficients are: \n{}'.format(results.params))
# Out:
# Mean squared error: 1079898296.62
#
# The coefficients are:
# CountryCitizen       14636.856161
# Gender                5725.502846
# Age                    762.920104
# MonthsProgramming      154.037280
# SchoolDegree          7407.894190
# dtype: float64

# %% [markdown]
# # Validation with sklearn

# %%
clf = LinearRegression()
clf.fit(X_train, y_train)

# The coefficients
print('Coefficients: \n', clf.coef_)
# The mean squared error
print("Mean squared error: %.2f"
      % np.mean((clf.predict(X_test) - y_test) ** 2))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % clf.score(X_test, y_test))
# Out:
# Coefficients:
#  [ 14791.86574234   5118.93697331    742.64744109    149.05303962
#    7906.90240264]
# Mean squared error: 1009699579.85
# Variance score: 0.18
